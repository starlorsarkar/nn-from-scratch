# %%
input = [[1,2,3,5],[4,5,6,7],[8,9,10,11]]
weight =[[0.2,0.8,0.4,0.6],[0.5,0.1,0.9,0.3],[0.4,0.7,0.2,0.8]]
bias = [0.5,0.1,0.3]
import numpy as np
input = np.array(input)
weight = np.array(weight)   
bias = np.array(bias)

output = np.dot(input,weight.T) + bias
print(output)    # This will give the final output after applying weights and bias where we have three neurons and this is one layer of neural network
# Out:
# [[ 6.5         5.0000001   6.7000001 ]
#  [11.89999962 10.1        12.19999962]
#  [19.89999962 17.30000076 20.59999924]]

# %%
x = [1,2,3]
w = [[0.2,0.4,0.6],[0.5,0.1,0.9]]
b = [0.5,0.1]

output = 0 

for i in range(len(w)):
    output = 0
    for j in range(len(x)):
        output += x[j] * w[i][j]
    output += b[i]
    print(output)
# Out:
# 3.3
# 3.5000000000000004

# %%
import numpy as np
import pandas as pd
x= [1,2,3]
w = [[0.2,0.4,0.6],[0.5,0.1,0.9]]
b = [0.5,0.1]
x = np.array(x)
w = np.array(w)
b = np.array(b)

output = np.dot(x,w.T) + b
print(output)
# Out:
# [3.29999995 3.5000001 ]

# %%
f = output
# now we will see the next layer of neural network where we have three neurons again and we will apply weights and bias to this output
weight2 = [[0.3,0.2,0.5],[0.6,0.1,0.4]] # weights for the second layer 2 cross 3
bias2 = [0.2,0.4,0.6]

weight2 = np.array(weight2)
bias2 = np.array(bias2)

output2 = np.dot(f,weight2) + bias2
print(output2)   # This will give the final output after applying weights and bias where we
# Out:
# [3.29000015 1.40999999 3.64999995]

# %%
#suppose we have two neurons in 2nd layer of neural network and this is second layer of neural network
#have three neurons and this is one layer of neural network
weight3 = [[0.5,0.2,0.3],[0.4,0.6,0.8]] #2 neurons 3 inputs
bias3 = [0.1,0.3]
weight3 = np.array(weight3)
bias3 = np.array(bias3)

output3 = np.dot(weight3,output2) + bias3
print(output3)   # This will give the final output after applying weights and bias where we
# Out:
# [3.12200007 5.38199978]

# %%
#suppose we have two neurons in 1st layer of neural network and this is second layer of neural  three batch of input where each input has four features

input = [[1,2,3,5],[4,5,6,7],[8,9,10,11]]
weight =[[0.2,0.8,0.4,0.6],[0.5,0.1,0.9,0.3]]
bias = [0.5,0.1]
import numpy as np
input = np.array(input)
weight = np.array(weight)
bias = np.array(bias)
output = np.dot(input,weight.T) + bias
print(output)    # This will give the final output after applying weights and bias where we have
# Out:
# [[ 6.5         5.0000001 ]
#  [11.89999962 10.1       ]
#  [19.89999962 17.30000076]]

# %% [markdown]
# Now we will try to handle non linear data

# %%
# !pip install nnfs
from nnfs.datasets import spiral_data
import nnfs
import numpy 
nnfs.init()
import matplotlib.pyplot as plt
X, y = spiral_data(samples=100, classes=3)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap="brg")
plt.show()

# %%
import numpy as np
import nnfs
from nnfs.datasets import spiral_data
nnfs.init()
# Dense layer
class Layer_Dense:
 # Layer initialization
 def __init__(self, n_inputs, n_neurons):
 # Initialize weights and biases
   self.weights = 0.01 * np.random.randn(n_inputs, n_neurons)
   self.biases = np.zeros((1, n_neurons))

 # Forward pass
 def forward(self, inputs):
 # Calculate output values from inputs, weights and biases
   self.output = np.dot(inputs, self.weights) + self.biases

# Create dataset
X, y = spiral_data(samples=100, classes=3)
# Create Dense layer with 2 input features and 3 output values
dense1 = Layer_Dense(2, 3)
# Perform a forward pass of our training data through this layer
dense1.forward(X)


# Let's see output of the first few samples:
print(dense1.output.shape)  # output of first layer
# Out:
# (300, 3)

# %%
print(layer1.output.shape)  # output of first layer
print(layer2.output.shape)  # output of second layer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(layer1.output.shape)  # output of first layer
#       2 print(layer2.output.shape)  # output of second layer
#
# NameError: name 'layer1' is not defined

# %%
print(layer2.output[:5])
# Out:
# [[ 0.0000000e+00  0.0000000e+00  0.0000000e+00  0.0000000e+00
#    0.0000000e+00  0.0000000e+00  0.0000000e+00  0.0000000e+00
#    0.0000000e+00  0.0000000e+00]
#  [ 1.4252591e-06  9.3868446e-10 -4.5882609e-07 -4.0773159e-07
#   -1.0384873e-06 -1.4848944e-06  1.1221587e-06  3.1823609e-07
#    3.6028453e-07 -7.4563667e-07]
#  [ 3.6610891e-06  8.2015134e-07 -1.4849653e-06 -7.2290169e-07
#   -2.5661723e-06 -4.5007228e-06  3.2880669e-06  2.0539385e-07
#   -3.0564789e-07 -1.7765640e-06]
#  [ 5.4950729e-06  2.9088587e-06 -2.8574618e-06 -4.1932489e-07
#   -3.6435947e-06 -8.1637836e-06  5.7673224e-06 -9.4756712e-07
#   -2.9847977e-06 -2.3817897e-06]
#  [ 7.5395883e-06  3.7049813e-06 -3.8134085e-06 -6.8887573e-07
#   -5.0347294e-06 -1.0961015e-05  7.7712120e-06 -1.0859378e-06
#   -3.6645181e-06 -3.3165259e-06]]

# %%
class activationRelu:
    def forward(self,inputs):
        self.output = np.maximum(0,inputs)

# %%
class softmax:
    
    def forward(self, inputs):
        exp = np.exp(inputs - np.max(inputs, axis=1, keepdims=True))
        self.output = exp / np.sum(exp, axis=1, keepdims=True)

# %%
X, y = spiral_data(samples=100, classes=3)

# Layer 1
layer1 = Layer_Dense(2, 3)
activation1 = activationRelu()

# Layer 2
layer2 = Layer_Dense(3, 3)
activation2 = softmax()

# Forward pass
layer1.forward(X)
activation1.forward(layer1.output)
layer2.forward(activation1.output)
activation2.forward(layer2.output)

print(activation2.output)
#100*3
# Out:
# [[0.33333334 0.33333334 0.33333334]
#  [0.33333355 0.33333308 0.3333334 ]
#  [0.33333334 0.33333334 0.33333334]
#  [0.33333367 0.33333293 0.33333343]
#  [0.33333334 0.33333334 0.33333334]
#  [0.33333388 0.3333326  0.3333335 ]
#  [0.33333623 0.33332947 0.33333427]
#  [0.33333844 0.33332658 0.333335  ]
#  [0.3333379  0.3333273  0.3333348 ]
#  [0.3333398  0.33332476 0.33333546]
#  [0.33334014 0.3333243  0.33333555]
#  [0.3333431  0.33332032 0.33333656]
#  [0.33334115 0.33332294 0.3333359 ]
#  [0.33334458 0.33331832 0.33333707]
#  [0.33334124 0.3333228  0.333336  ]
#  [0.33334628 0.33331612 0.33333763]
#  [0.33334738 0.33331466 0.33333796]
#  [0.33334842 0.33331326 0.33333835]
#  [0.33334315 0.33332026 0.33333665]
#  [0.33335    0.33331114 0.33333886]
#  [0.33335108 0.33330965 0.3333392 ]
#  [0.33335197 0.3333085  0.3333395 ]
#  [0.33335283 0.33330736 0.3333398 ]
#  [0.33335292 0.33330724 0.33333987]
#  [0.3333384  0.33332607 0.3333355 ]
#  [0.3333338  0.33333197 0.33333427]
# ...

# %%
softmax_outputs = np.array([[0.7, 0.1, 0.2],
 [0.1, 0.5, 0.4],
 [0.02, 0.9, 0.08]])
class_targets = [0, 1, 1]
print(softmax_outputs[range(len(softmax_outputs)), class_targets])
# Out:
# [0.7 0.5 0.9]

# %%
print(-np.log(softmax_outputs[range(len(softmax_outputs)), class_targets]))
neg_log = -np.log(softmax_outputs[range(len(softmax_outputs)), class_targets])
print(neg_log)

avg_loss = np.mean(neg_log) 
avg_loss
# Out:
# [0.35667494 0.69314718 0.10536052]
# [0.35667494 0.69314718 0.10536052]
# np.float64(0.38506088005216804)

# %%
y_pred = [[1,0,0], [0,1,0], [0,0,1]]
y_true = np.array([[0.7, 0.1, 0.2],
 [0.1, 0.5, 0.4],
 [0.02, 0.9, 0.08]])

y_pred = np.array(y_pred)
y_true = np.array(y_true)

A =y_pred*y_true
b = np.sum(A, axis=1)
c = -np.log(b)
print(c)
np.mean(c)
# Out:
# [0.35667494 0.69314718 2.52572864]
# np.float64(1.191850256268978)

# %%
class Loss:
    def calculate(self, output, y):
        sample_losses = self.forward(output, y)
        data_loss = np.mean(sample_losses)
        return data_loss

# %%
class categorical_cross_entropy(Loss):
    def forward(self, y_pred, y_true):

        samples = len(y_pred)

        y_pred_clipped = np.clip(y_pred, 1e-7, 1 - 1e-7)

        if len(y_true.shape) == 1:
            correct_confidences = y_pred_clipped[range(samples), y_true]

        elif len(y_true.shape) == 2:
            correct_confidences = np.sum(y_pred_clipped * y_true, axis=1)

        negative_log_likelihoods = -np.log(correct_confidences)

        return negative_log_likelihoods
loss_function = categorical_cross_entropy()

# %%
class accuracy:
    def calculate(self, y_pred, y_true):
        predictions = np.argmax(y_pred, axis=1)
        if len(y_true.shape) == 2:
            y_true = np.argmax(y_true, axis=1)
        accuracy = np.mean(predictions == y_true)
        return accuracy

# %%
X, y = spiral_data(samples=100, classes=3)

# Layer 1
layer1 = Layer_Dense(2, 3)
activation1 = activationRelu()

# Layer 2
layer2 = Layer_Dense(3, 3)
activation2 = softmax()

loss = categorical_cross_entropy()

# Forward pass
layer1.forward(X)
activation1.forward(layer1.output)
layer2.forward(activation1.output)
activation2.forward(layer2.output)

print(activation2.output) #This is the Output layer and the output shape is 100*3 and this is the output of 100 samples and each sample has three output values and these three output values are the probabilities of each class and the sum of these three output values will be 1 because we have applied softmax activation function in the output layer and this is the final output of our neural network and now we will calculate the loss value using categorical cross entropy loss function and we will pass the output of the output layer and the true labels to the loss function and it will give us the loss value which is a measure of how well our neural network is performing and we want to minimize this loss value by adjusting the weights and biases of our neural network using backpropagation algorithm and this is how we train our neural network to make accurate predictions on new data

loss_value = loss.calculate(activation2.output, y)
print("Loss value:", loss_value)
# Out:
# [[0.33333334 0.33333334 0.33333334]
#  [0.3333332  0.3333336  0.3333332 ]
#  [0.33333308 0.33333394 0.333333  ]
#  [0.33333302 0.3333341  0.3333329 ]
#  [0.33333284 0.33333457 0.33333266]
#  [0.3333333  0.33333322 0.3333335 ]
#  [0.33333334 0.33333334 0.33333334]
#  [0.3333333  0.33333328 0.33333343]
#  [0.33333313 0.33333296 0.33333385]
#  [0.33333334 0.33333334 0.33333334]
#  [0.33333334 0.33333334 0.33333334]
#  [0.3333331  0.33333293 0.33333394]
#  [0.33333334 0.33333334 0.33333334]
#  [0.33333316 0.33333305 0.33333382]
#  [0.3333332  0.33333308 0.33333376]
#  [0.33333305 0.3333319  0.33333507]
#  [0.33333296 0.33333263 0.33333442]
#  [0.3333334  0.33332977 0.33333683]
#  [0.3333332  0.33333    0.3333368 ]
#  [0.3333329  0.3333322  0.33333492]
#  [0.333333   0.33333093 0.33333614]
#  [0.33333302 0.33333036 0.33333662]
#  [0.33333164 0.33333644 0.3333319 ]
#  [0.3333328  0.33333164 0.33333555]
#  [0.3333333  0.3333285  0.33333823]
#  [0.33333272 0.33333188 0.33333534]
# ...

# %%
import matplotlib.pyplot as plt
from nnfs.datasets import vertical_data
import nnfs
nnfs.init()

x,y = vertical_data(samples=100, classes=3)
plt.scatter(x[:, 0], x[:, 1], c=y, cmap="brg")
plt.show()

# %%
x,y = vertical_data(samples=100, classes=3)
dense1 = Layer_Dense(2, 3)
activation1 = activationRelu()

dense2 = Layer_Dense(3, 3)
activation2 = softmax()

loss = categorical_cross_entropy()

dense1.forward(x)
activation1.forward(dense1.output)
dense2.forward(activation1.output)
activation2.forward(dense2.output)
print(activation2.output)

loss_value = loss.calculate(activation2.output, y)
print("Loss value:", loss_value)
# Out:
# [[0.3333332  0.33333376 0.33333308]
#  [0.33333322 0.33333358 0.33333316]
#  [0.33333004 0.33334035 0.33332962]
#  [0.33333072 0.33333898 0.33333033]
#  [0.33333328 0.33333343 0.33333325]
#  [0.3333306  0.3333391  0.33333024]
#  [0.33332902 0.33334252 0.33332846]
#  [0.33333325 0.33333355 0.3333332 ]
#  [0.3333333  0.33333343 0.3333333 ]
#  [0.33333325 0.33333355 0.33333322]
#  [0.33333316 0.3333337  0.3333331 ]
#  [0.33333328 0.33333346 0.3333332 ]
#  [0.33333316 0.3333337  0.3333331 ]
#  [0.33333325 0.33333355 0.33333322]
#  [0.33333325 0.33333358 0.33333316]
#  [0.33333328 0.33333346 0.3333332 ]
#  [0.33333316 0.33333373 0.3333331 ]
#  [0.33333325 0.33333358 0.33333316]
#  [0.33332878 0.33334303 0.33332816]
#  [0.33333325 0.33333358 0.33333316]
#  [0.33333322 0.3333336  0.33333316]
#  [0.33333322 0.33333358 0.33333316]
#  [0.33333325 0.33333343 0.33333325]
#  [0.33333325 0.33333352 0.33333322]
#  [0.33333322 0.33333358 0.33333316]
#  [0.33333322 0.3333336  0.33333316]
# ...

# %%
x,y = vertical_data(samples=100, classes=3)
dense1 = Layer_Dense(2, 3)
activation1 = activationRelu()

dense2 = Layer_Dense(3, 3)
activation2 = softmax()

loss = categorical_cross_entropy()

dense1.forward(x)
activation1.forward(dense1.output)
dense2.forward(activation1.output)
activation2.forward(dense2.output)
print(activation2.output)

loss_value = loss.calculate(activation2.output, y)
print("Loss value:", loss_value)
lowest_loss = 99999  # Initialize lowest loss to a very large number

dense1_weights = dense1.weights.copy()
dense1_biases = dense1.biases.copy()
dense2_weights = dense2.weights.copy()
dense2_biases = dense2.biases.copy()

for iteration in range(10000):
    # Generate random weights and biases
    dense1.weights = 0.05 * np.random.randn(2, 3)
    dense1.biases = np.zeros((1, 3))
    dense2.weights = 0.05 * np.random.randn(3, 3)
    dense2.biases = np.zeros((1, 3))

    # Forward pass
    dense1.forward(x)
    activation1.forward(dense1.output)
    dense2.forward(activation1.output)
    activation2.forward(dense2.output)

    # Calculate loss
    loss_value = loss.calculate(activation2.output, y)
    
    prediction = np.argmax(activation2.output, axis=1)
    
    accuracy= np.mean(prediction == y)
    
    #if loss is less than lowest loss then we will save the weights and biases
    if loss_value < lowest_loss:
        print("New set of weights and biases found, iteration:", iteration, "loss:", loss_value, "accuracy:", accuracy)
        lowest_loss = loss_value
        dense1_weights = dense1.weights.copy()
        dense1_biases = dense1.biases.copy()
        dense2_weights = dense2.weights.copy()
        dense2_biases = dense2.biases.copy()
        
# After 10000 iterations we will have the best weights and biases that give us the lowest loss value and highest accuracy and we can use these weights and biases to make predictions on new data
# Out:
# [[0.33333018 0.33332676 0.3333431 ]
#  [0.33332968 0.33332574 0.3333446 ]
#  [0.33332992 0.33332625 0.33334383]
#  [0.33332995 0.3333263  0.3333437 ]
#  [0.3333297  0.3333258  0.33334452]
#  [0.3333295  0.3333254  0.33334512]
#  [0.33333027 0.33332697 0.3333428 ]
#  [0.33333007 0.33332655 0.3333434 ]
#  [0.33333078 0.33332804 0.33334112]
#  [0.33332938 0.33332506 0.3333456 ]
#  [0.33333012 0.33332667 0.33334318]
#  [0.33333093 0.33332834 0.33334076]
#  [0.33332998 0.33332634 0.33334368]
#  [0.3333291  0.33332452 0.33334637]
#  [0.33333093 0.3333283  0.3333408 ]
#  [0.33332992 0.3333262  0.33334386]
#  [0.33332923 0.33332476 0.33334604]
#  [0.33333004 0.33332655 0.3333434 ]
#  [0.33333138 0.3333293  0.33333933]
#  [0.33333093 0.3333283  0.33334076]
#  [0.3333309  0.33332828 0.33334085]
#  [0.33333087 0.33332825 0.33334085]
#  [0.33333012 0.33332667 0.33334318]
#  [0.33332977 0.33332598 0.33334425]
#  [0.33332932 0.333325   0.33334574]
#  [0.33333132 0.33332908 0.3333396 ]
# ...

# %%
lowest_loss = 999999  # Initialize lowest loss to a very large number
dense1_weights = dense1.weights.copy()
dense1_biases = dense1.biases.copy()
dense2_weights = dense2.weights.copy()
dense2_biases = dense2.biases.copy()

for iteration in range(10000):
    # Generate random weights and biases
    dense1.weights += 0.05 * np.random.randn(2, 3)
    dense1.biases += np.zeros((1, 3))
    dense2.weights += 0.05 * np.random.randn(3, 3)
    dense2.biases += np.zeros((1, 3))

    # Forward pass
    dense1.forward(x)
    activation1.forward(dense1.output)
    dense2.forward(activation1.output)
    activation2.forward(dense2.output)

    # Calculate loss
    loss_value = loss.calculate(activation2.output, y)
    
    prediction = np.argmax(activation2.output, axis=1)
    
    accuracy= np.mean(prediction == y)
    
    #if loss is less than lowest loss then we will save the weights and biases
    if loss_value < lowest_loss:
        print("New set of weights and biases found, iteration:", iteration, "loss:", loss_value, "accuracy:", accuracy)
        lowest_loss = loss_value
        dense1_weights = dense1.weights.copy()
        dense1_biases = dense1.biases.copy()
        dense2_weights = dense2.weights.copy()
        dense2_biases = dense2.biases.copy()
        
# After 10000 iterations we will have the best weights and biases that give us the lowest loss value and highest accuracy and we can use these weights and biases to make predictions on new data
# Out:
# New set of weights and biases found, iteration: 0 loss: 3.686539 accuracy: 0.3333333333333333
# New set of weights and biases found, iteration: 1 loss: 3.6862395 accuracy: 0.3333333333333333
# New set of weights and biases found, iteration: 193 loss: 3.6608944 accuracy: 0.3333333333333333
# New set of weights and biases found, iteration: 195 loss: 3.6471725 accuracy: 0.3333333333333333
# New set of weights and biases found, iteration: 199 loss: 3.6443572 accuracy: 0.3333333333333333
# New set of weights and biases found, iteration: 203 loss: 3.6354167 accuracy: 0.3333333333333333
# New set of weights and biases found, iteration: 205 loss: 3.6150546 accuracy: 0.3333333333333333
# New set of weights and biases found, iteration: 206 loss: 3.6044645 accuracy: 0.3333333333333333
# New set of weights and biases found, iteration: 208 loss: 3.5986288 accuracy: 0.3333333333333333
# New set of weights and biases found, iteration: 210 loss: 3.5723221 accuracy: 0.3333333333333333
# ...

# %% [markdown]
# Coding Backprop

# %%
import numpy as np

weight = np.array([0.5, -0.3, 0.8])  # for one neuron
bias = 1  # for one neuron

input = np.array([1, 2, 3])  # input for one neuron

target_output = 0 
learning_rate = 0.001

def relu(x):
    return np.maximum(0, x)

def relu_derivative(x):
    return np.where(x > 0, 1, 0)

for iteration in range(20):
    # forward pass 
    linear_output = np.dot(input, weight.T) + bias
    predicted_output = relu(linear_output)
    # calculate loss
    loss = (predicted_output - target_output) ** 2
    print("Iteration:", iteration, "Loss:", loss)
    # calculate gradients
    d_predicted_output = 2 * (predicted_output - target_output)
    d_linear_output = d_predicted_output * relu_derivative(linear_output)
    d_weight = input * d_linear_output
    d_bias = d_linear_output
    # update weights and bias
    weight -= learning_rate * d_weight
    bias -= learning_rate * d_bias
print("Final weights:", weight)
print("Final bias:", bias)
print("Final loss:", loss)
print("Predicted output:", predicted_output)
# Out:
# Iteration: 0 Loss: 10.889999
# Iteration: 1 Loss: 10.246401747914328
# Iteration: 2 Loss: 9.64083806119522
# Iteration: 3 Loss: 9.071064897201776
# Iteration: 4 Loss: 8.534965357320646
# Iteration: 5 Loss: 8.030548902500376
# Iteration: 6 Loss: 7.555943519213352
# Iteration: 7 Loss: 7.109387102479862
# Iteration: 8 Loss: 6.689221996093931
# Iteration: 9 Loss: 6.293889124537586
# Iteration: 10 Loss: 5.921920682036108
# Iteration: 11 Loss: 5.571935111329848
# Iteration: 12 Loss: 5.242633422225478
# Iteration: 13 Loss: 4.932793960459653
# Iteration: 14 Loss: 4.641265974524631
# Iteration: 15 Loss: 4.366966770019087
# Iteration: 16 Loss: 4.108879351904962
# Iteration: 17 Loss: 3.8660443696935305
# Iteration: 18 Loss: 3.6375612190984508
# Iteration: 19 Loss: 3.4225812572154615
# Final weights: [ 0.39963476 -0.50073049  0.49890427]
# Final bias: 0.89963475543422
# Final loss: 3.4225812572154615
# Predicted output: 1.8500219612792335

# %% [markdown]
# Multiple neurons

# %%
inputs = np.array([1, 2, 3,5])  # input for one neuron
weights = np.array([[0.5, -0.3, 0.8,0.9],
                    [0.2, 0.1, -0.4,0.7],
                    [-0.1, 0.6, 0.3,0.5]])  # for three neurons
biases = np.array([0.5, 0.1, 0.3])  # for three neurons

learning_rate = 0.001

def relu(x):
    return np.maximum(0, x)
def relu_derivative(x):
    return np.where(x > 0, 1, 0)

for iteration in range(200):
    z = np.dot(weights, inputs) + biases
    a = relu(z)
    y = sum(a)  # target output
    loss = y**2
    print("Iteration:", iteration, "Loss:", loss)
    d_y = 2 * y 
    d_a = np.ones_like(a)
    d_z = d_y * d_a * relu_derivative(z)
    d_weights = np.outer(d_z, inputs)
    d_biases = d_z
    weights -= learning_rate * d_weights
    biases -= learning_rate * d_biases
print("Final weights:", weights)
print("Final biases:", biases)
print("Final loss:", loss)
# Out:
# Iteration: 0 Loss: 222.01000710487367
# Iteration: 1 Loss: 128.23298042991718
# Iteration: 2 Loss: 74.06736453090667
# Iteration: 3 Loss: 42.78131309545748
# Iteration: 4 Loss: 30.03744488990319
# Iteration: 5 Loss: 21.194420364453812
# Iteration: 6 Loss: 14.954782658393682
# Iteration: 7 Loss: 10.552095302907334
# Iteration: 8 Loss: 7.445558810161698
# Iteration: 9 Loss: 5.740984668361464
# Iteration: 10 Loss: 4.859169003971786
# Iteration: 11 Loss: 4.11280058873971
# Iteration: 12 Loss: 3.481074526828278
# Iteration: 13 Loss: 2.9463817101040153
# Iteration: 14 Loss: 2.4938172393488403
# Iteration: 15 Loss: 2.110766954203376
# Iteration: 16 Loss: 1.786553138363979
# Iteration: 17 Loss: 1.5121386535472086
# Iteration: 18 Loss: 1.2798741625429297
# Iteration: 19 Loss: 1.0832854869251518
# Iteration: 20 Loss: 0.9168928094005249
# Iteration: 21 Loss: 0.7760580241275632
# Iteration: 22 Loss: 0.6568555355068656
# Iteration: 23 Loss: 0.5559625382949451
# ...
