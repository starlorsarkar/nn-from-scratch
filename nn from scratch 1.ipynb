# %% [markdown]
# Neural Network From Scratch

# %%
import numpy as np
input = [1,2,3,4]
input = np.array(input)
weights = [0.1,0.22,0.35,-0.5]
weights = np.array(weights)
bias = 2

output = np.dot(input,weights.transpose()) + bias
print(output)
# Out:
# 1.5899999999999999

# %%
# Out:
# (4,)

# %%
import numpy as np
input = [1,2,3,4]
input = np.array(input)
weights = [[0.1,0.22,0.35,-0.5],[0.1,0.22,0.35,-0.5],[0.1,0.22,0.35,-0.5]]
weights = np.array(weights)
bias = [2,3,0.5]
bias = np.array(bias)

output1 = np.dot(weights,input) + bias
print(output1)
# Out:
# [1.59 2.59 0.09]

# %%
input2 = output1
weights1 = [
    [0.5, 0.8, 0.1],
    [0.5, 0.8, 0.1],
    [0.5, 0.8, 0.1],
    [0.5, 0.8, 0.1],
    [0.5, 0.8, 0.1]
]
weights1 = np.array(weights1)
weights1.shape
bias1 = [2,3,0.5,1,0]
bias1 = np.array(bias1)

output2 = np.dot(weights1,input2) + bias1
print(output2)
# Out:
# [4.876 5.876 3.376 3.876 2.876]

# %%
1.59*0.5+2.59*0.8+0.09*0.1+2
